# %%
p = Pmf(range(1,7))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6892655d2fd7> in <module>()
# ----> 1 p = Pmf({1: 1, 2: 1, 3: 1, 4: 1, 5: 1, 6: 1})
#
# NameError: name 'Pmf' is not defined

# %%
from thinkbayes2 import *
import thinkplot
p = Pmf(range(1,7))
thinkplot.Hist(p)

# %%
from thinkbayes2 import *
import thinkplot
p = Pmf(range(1,7))
thinkplot.Hist(p + p)

# %%
from thinkbayes2 import *
import thinkplot
p = Pmf(range(1,7))
thinkplot.Hist(p + p + p)

# %%
from thinkbayes2 import *
import thinkplot
p = Pmf(range(1,7))
thinkplot.Hist(p + p + p + p)

# %%
from thinkbayes2 import *
import thinkplot
p = Pmf(range(1,7))
thinkplot.Hist(p + p + p + p + p)

# %%
from thinkbayes2 import *
import thinkplot
p = Pmf(range(1,7))
thinkplot.Pmf(p + p + p + p + p)

# %%
from thinkbayes2 import *
import thinkplot
p = Pmf(range(1,7))
three_p = p + p + p
print three_p.Mean()
print three_p.Var()
print three_p.Var()**.5
# Out:
# 10.5
# 8.75
# 2.95803989155

# %%
print three_p.ProbGreater(15.5)
# Out:
# 0.0462962962963

# %%
print(dir(three_p))
# Out:
# ['AddConstant', 'AddPmf', 'Copy', 'CredibleInterval', 'Exp', 'GetDict', 'Incr', 'Items', 'Largest', 'Log', 'MakeCdf', 'Max', 'MaxLike', 'MaximumLikelihood', 'Mean', 'Mult', 'Normalize', 'Percentile', 'Print', 'Prob', 'ProbGreater', 'ProbLess', 'Probs', 'Random', 'Remove', 'Render', 'Scale', 'Set', 'SetDict', 'Smallest', 'SubPmf', 'Total', 'Values', 'Var', '__add__', '__class__', '__contains__', '__delattr__', '__delitem__', '__dict__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__weakref__', 'd', 'iterkeys', 'label', 'log']

# %%
print three_p.Random()
print three_p
# Out:
# 14
# Pmf({3: 0.004629629629629629, 4: 0.013888888888888888, 5: 0.027777777777777776, 6: 0.046296296296296294, 7: 0.06944444444444445, 8: 0.09722222222222222, 9: 0.11574074074074073, 10: 0.125, 11: 0.125, 12: 0.11574074074074074, 13: 0.09722222222222224, 14: 0.06944444444444445, 15: 0.046296296296296294, 16: 0.027777777777777776, 17: 0.013888888888888888, 18: 0.004629629629629629})

# %%
from thinkbayes2 import *
import thinkplot
p = Pmf(range(1,7))
three_p = p + p + p
for i in range(3,9):
    three_p.Remove(i)
three_p.Normalize()
print three_p.ProbGreater(16)
# Out:
# 0.025
