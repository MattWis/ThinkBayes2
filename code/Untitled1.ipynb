# %%
import unittest
import thinkbayes2
import thinkplot
d6 = thinkbayes2.Pmf(range(1,7))

# %%
cd6 = d6.MakeCdf()
print str(cd6.MakePmf())
print str(d6)
print "How do I check equality wrt floating collections?"
# Out:
# Pmf({1: 0.16666666666666669, 2: 0.16666666666666669, 3: 0.16666666666666674, 4: 0.16666666666666663, 5: 0.16666666666666663, 6: 0.16666666666666663})
# Pmf({1: 0.16666666666666666, 2: 0.16666666666666666, 3: 0.16666666666666666, 4: 0.16666666666666666, 5: 0.16666666666666666, 6: 0.16666666666666666})
# Pmf({0: 0.16666666666666663, 1: 0.13888888888888887, 2: 0.1111111111111111, 3: 0.083333333333333315, 4: 0.055555555555555539, 5: 0.027777777777777769, -1: 0.13888888888888887, -5: 0.02777777777777778, -4: 0.055555555555555559, -3: 0.083333333333333343, -2: 0.1111111111111111})
# How do I check equality wrt floating collections?

# %%
thinkplot.Hist(d6)

# %%
thinkplot.Cdf(cd6)
# Out:
# {'xscale': 'linear', 'yscale': 'linear'}

# %%
thinkplot.Cdf(three.Max(6))
# Out:
# {'xscale': 'linear', 'yscale': 'linear'}

# %%
from dice import Dice
d = {4:2, 6:6, 8:3, 10:2, 12:4, 20:4}
pmf = Dice(d)
thinkplot.Hist(pmf)

# %%
pmf.Update(6)
pmf.Update(6)
pmf.Update(5)
pmf.Update(8)
thinkplot.Hist(pmf)
